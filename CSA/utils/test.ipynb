# %%
inp = "{{0,0,0,0},{2,0,0,0},{1,3,0,0},{2,0,0,0},{10,0,0,0},{11,0,0,0},{0,0,0,0},{8,0,0,0},{7,0,0,0},{15,0,0,0},{16,4,0,0},{5,0,0,0},{0,0,0,0},{19,0,0,0},{15,0,0,0},{14,9,0,0},{10,17,0,0},{16,18,23,0},{17,0,0,0},{13,0,0,0},{21,0,0,0},{20,27,0,0},{28,0,0,0},{29,17,0,0},{0,0,0,0},{26,0,0,0},{25,27,0,0},{26,21,0,0},{22,34,0,0},{23,30,0,0},{29,0,0,0},{32,0,0,0},{31,0,0,0},{0,0,0,0},{28,35,0,0},{34,0,0,0},{0,0,0,0}}"

inp = inp.replace('{', '[').replace('}', ']')
walls = eval(inp)
walls.pop(0)

GRID_SIZE = 6

for n in range(len(walls)):
    i0 = n // GRID_SIZE
    j0 = n % GRID_SIZE

    for m in range(len(walls[n])):
        p = walls[n][m]-1
        if (p > -1):
            i1 = p // GRID_SIZE
            j1 = p % GRID_SIZE

        


print(*walls, sep='\n')
# Out:
# [1, -1, -1, -1]
# [0, 2, -1, -1]
# [1, -1, -1, -1]
# [9, -1, -1, -1]
# [10, -1, -1, -1]
# [-1, -1, -1, -1]
# [7, -1, -1, -1]
# [6, -1, -1, -1]
# [14, -1, -1, -1]
# [15, 3, -1, -1]
# [4, -1, -1, -1]
# [-1, -1, -1, -1]
# [18, -1, -1, -1]
# [14, -1, -1, -1]
# [13, 8, -1, -1]
# [9, 16, -1, -1]
# [15, 17, 22, -1]
# [16, -1, -1, -1]
# [12, -1, -1, -1]
# [20, -1, -1, -1]
# [19, 26, -1, -1]
# [27, -1, -1, -1]
# [28, 16, -1, -1]
# [-1, -1, -1, -1]
# [25, -1, -1, -1]
# [24, 26, -1, -1]
# [25, 20, -1, -1]
# [21, 33, -1, -1]
# [22, 29, -1, -1]
# [28, -1, -1, -1]
# [31, -1, -1, -1]
# [30, -1, -1, -1]
# [-1, -1, -1, -1]
# [27, 34, -1, -1]
# [33, -1, -1, -1]
# [-1, -1, -1, -1]
